# %%
import pandas as pd 

import spacy
import neuralcoref

from pathlib import Path

from email import policy
from email.parser import BytesParser
import json
import nltk.data
import re
import os
nlp = spacy.load('en_core_web_sm')
neuralcoref.add_to_pipe(nlp)

#finding the files that has the keyword like meeting or conference in their text. 
hitlist=[]

user_input = input('What is the name of your directory')
directory = os.listdir(user_input)
#print(directory)

###YOU CAN ADD MORE TRAVEL RELATED KEYWORDS HERE!!!!
keywords=['travel','landed','trip','flying','visit','journeyed','en route','meeting','tour','pilgrimage','holiday',
          'outing','excursion','cruise','voyage','safari','trek','jaunt','wander','event']


for fname in directory:
        if os.path.isfile(user_input + os.sep + fname):
        
            with open(user_input + os.sep + fname, 'rb') as f:
                name = f.name  # Get file name
                msg = BytesParser(policy=policy.default).parse(f)
            print(name)
     
        
            if(msg.get_body(preferencelist=('plain'))):
                text = msg.get_body(preferencelist=('plain')).get_content()    
             
            else:
                print('invalid')
                continue
           
            text = textcleaning(text)
            text = coref_resolution(text)
            #print(text)
            #split to sentence and find if the keyword is in the sentence; perform NER and add this file to hitlist only if 
            #there are a person entity and a location in that sentence
            tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

            sent= text.split('.')
            #print(sent)
            for t in sent:
                    #print('\n')
                    per=0
                   
                    locn=0
                    doc=nlp(t)#SPACY NER TOOL IS USED TO IDENTIFY IF THERE ARE PERSONS/LOCATION IN A SENTENCE
                    
                    for ent in doc.ents:
                        #print(ent.text,ent.label_)
                        
                        if ent.label_=="PERSON" or ent.label_=="NORP":
                            per=per+1
                           
                        elif ent.label_=="LOC" or ent.label_== "GPE":
                            locn=locn+1
                            
            
                    for searchstring in keywords:
                        res = bytes(searchstring, 'utf-8')
                        if ( per>0) and (locn > 0) and (res.decode("utf-8") in text):
              
                            #print('found string in file',res,fname)
                            if fname not in hitlist:
                                print('found string in file',res,fname)
                                hitlist.append(fname)
                        #break
           #prints the filenames which has some travel relevant keywords. Start reading and label trips of these files
with open("OUTPUT.txt", "a") as o:
    for item in hitlist:
        # write each item on a new line
        o.write("%s\n" % item)
# Out:
# What is the name of your directoryemails-1
# emails-1/54194.eml
# emails-1/56783.eml
# emails-1/56797.eml
# emails-1/54180.eml
# found string in file b'event' 54180.eml
# found string in file b'event' 54180.eml
# emails-1/54157.eml
# emails-1/54143.eml
# emails-1/56807.eml
# emails-1/56393.eml
# found string in file b'event' 56393.eml
# emails-1/56387.eml
# emails-1/54221.eml
# emails-1/54235.eml
# found string in file b'event' 54235.eml
# found string in file b'event' 54235.eml
# emails-1/56378.eml
# emails-1/54209.eml
# emails-1/56379.eml
# emails-1/54208.eml
# emails-1/54234.eml
# emails-1/54220.eml
# emails-1/56386.eml
# emails-1/56392.eml
# emails-1/56806.eml
# emails-1/56812.eml
# emails-1/54142.eml
# emails-1/54156.eml
# emails-1/54181.eml
# emails-1/56796.eml
# emails-1/56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# found string in file b'travel' 56782.eml
# found string in file b'visit' 56782.eml
# found string in file b'meeting' 56782.eml
# found string in file b'tour' 56782.eml
# found string in file b'event' 56782.eml
# emails-1/54195.eml
# emails-1/56794.eml
# emails-1/54183.eml
# found string in file b'event' 54183.eml
# found string in file b'event' 54183.eml
# emails-1/54197.eml
# emails-1/54140.eml
# found string in file b'travel' 54140.eml
# found string in file b'visit' 54140.eml
# found string in file b'meeting' 54140.eml
# emails-1/54154.eml
# emails-1/54168.eml
# emails-1/56804.eml
# invalid
# emails-1/56810.eml
# emails-1/56384.eml
# emails-1/56390.eml
# emails-1/54236.eml
# emails-1/54222.eml
# emails-1/54223.eml
# found string in file b'event' 54223.eml
# found string in file b'event' 54223.eml
# emails-1/54237.eml
# found string in file b'travel' 54237.eml
# emails-1/56391.eml
# emails-1/56385.eml
# emails-1/56811.eml
# found string in file b'trip' 56811.eml
# found string in file b'meeting' 56811.eml
# found string in file b'trip' 56811.eml
# found string in file b'meeting' 56811.eml
# found string in file b'trip' 56811.eml
# found string in file b'meeting' 56811.eml
# found string in file b'trip' 56811.eml
# found string in file b'meeting' 56811.eml
# found string in file b'trip' 56811.eml
# found string in file b'meeting' 56811.eml
# found string in file b'trip' 56811.eml
# found string in file b'meeting' 56811.eml
# found string in file b'trip' 56811.eml
# found string in file b'meeting' 56811.eml
# emails-1/56805.eml
# emails-1/54169.eml
# emails-1/54155.eml
# emails-1/54141.eml
# emails-1/56781.eml
# emails-1/54196.eml
# emails-1/54182.eml
# emails-1/56795.eml
# emails-1/56791.eml
# emails-1/54186.eml
# emails-1/54192.eml
# emails-1/56785.eml
# emails-1/54179.eml
# emails-1/54145.eml
# emails-1/54151.eml
# emails-1/56801.eml
# emails-1/.DS_Store
# invalid
# emails-1/56381.eml
# emails-1/56395.eml
# emails-1/54233.eml
# emails-1/54227.eml
# emails-1/54226.eml
# found string in file b'visit' 54226.eml
# found string in file b'event' 54226.eml
# found string in file b'visit' 54226.eml
# found string in file b'event' 54226.eml
# found string in file b'visit' 54226.eml
# found string in file b'event' 54226.eml
# emails-1/54232.eml
# emails-1/56394.eml
# emails-1/56380.eml
# found string in file b'event' 56380.eml
# found string in file b'event' 56380.eml
# emails-1/56800.eml
# emails-1/54150.eml
# emails-1/54144.eml
# emails-1/54178.eml
# emails-1/56784.eml
# emails-1/54193.eml
# emails-1/54187.eml
# found string in file b'visit' 54187.eml
# found string in file b'visit' 54187.eml
# found string in file b'visit' 54187.eml
# found string in file b'visit' 54187.eml
# found string in file b'visit' 54187.eml
# found string in file b'visit' 54187.eml
# found string in file b'visit' 54187.eml
# found string in file b'visit' 54187.eml
# found string in file b'visit' 54187.eml
# emails-1/56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# found string in file b'travel' 56790.eml
# found string in file b'trip' 56790.eml
# found string in file b'meeting' 56790.eml
# found string in file b'tour' 56790.eml
# found string in file b'event' 56790.eml
# emails-1/54191.eml
# emails-1/56786.eml
# emails-1/56792.eml
# emails-1/54185.eml
# emails-1/54152.eml
# emails-1/54146.eml
# emails-1/56802.eml
# emails-1/56396.eml
# emails-1/56382.eml
# emails-1/54218.eml
# found string in file b'event' 54218.eml
# found string in file b'event' 54218.eml
# found string in file b'event' 54218.eml
# emails-1/54224.eml
# emails-1/54230.eml
# emails-1/54231.eml
# emails-1/54225.eml
# found string in file b'meeting' 54225.eml
# emails-1/54219.eml
# found string in file b'visit' 54219.eml
# found string in file b'visit' 54219.eml
# found string in file b'visit' 54219.eml
# found string in file b'visit' 54219.eml
# found string in file b'visit' 54219.eml
# found string in file b'visit' 54219.eml
# found string in file b'visit' 54219.eml
# found string in file b'visit' 54219.eml
# found string in file b'visit' 54219.eml
# found string in file b'visit' 54219.eml
# emails-1/56383.eml
# found string in file b'meeting' 56383.eml
# emails-1/56397.eml
# emails-1/56803.eml
# invalid
# emails-1/54147.eml
# emails-1/54153.eml
# emails-1/54184.eml
# emails-1/56793.eml
# emails-1/56787.eml
# emails-1/54190.eml
# emails-1/54134.eml
# emails-1/54120.eml
# emails-1/54108.eml
# invalid
# emails-1/54281.eml
# invalid
# emails-1/54242.eml
# emails-1/54256.eml
# emails-1/57011.eml
# emails-1/57010.eml
# emails-1/54257.eml
# emails-1/54243.eml
# emails-1/54280.eml
# emails-1/54109.eml
# emails-1/54121.eml
# emails-1/54135.eml
# emails-1/54123.eml
# emails-1/54137.eml
# emails-1/54282.eml
# invalid
# emails-1/54255.eml
# emails-1/54241.eml
# emails-1/57006.eml
# emails-1/54269.eml
# emails-1/57012.eml
# emails-1/57013.eml
# emails-1/57007.eml
# invalid
# emails-1/54268.eml
# emails-1/54240.eml
# found string in file b'landed' 54240.eml
# found string in file b'event' 54240.eml
# found string in file b'landed' 54240.eml
# found string in file b'event' 54240.eml
# found string in file b'landed' 54240.eml
# found string in file b'event' 54240.eml
# found string in file b'landed' 54240.eml
# found string in file b'event' 54240.eml
# found string in file b'landed' 54240.eml
# found string in file b'event' 54240.eml
# emails-1/54254.eml
# emails-1/54283.eml
# emails-1/54136.eml
# emails-1/54122.eml
# emails-1/54126.eml
# emails-1/54132.eml
# found string in file b'visit' 54132.eml
# emails-1/54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# found string in file b'meeting' 54287.eml
# found string in file b'event' 54287.eml
# emails-1/57017.eml
# emails-1/54278.eml
# found string in file b'trip' 54278.eml
# found string in file b'trip' 54278.eml
# found string in file b'trip' 54278.eml
# emails-1/54250.eml
# found string in file b'event' 54250.eml
# emails-1/54244.eml
# emails-1/54245.eml
# found string in file b'meeting' 54245.eml
# found string in file b'event' 54245.eml
# emails-1/54251.eml
# emails-1/57016.eml
# emails-1/54279.eml
# found string in file b'meeting' 54279.eml
# found string in file b'event' 54279.eml
# found string in file b'meeting' 54279.eml
# found string in file b'event' 54279.eml
# emails-1/54286.eml
# emails-1/54133.eml
# emails-1/54127.eml
# emails-1/54119.eml
# emails-1/54131.eml
# emails-1/54125.eml
# emails-1/54284.eml
# emails-1/57014.eml
# emails-1/54247.eml
# emails-1/57028.eml
# emails-1/54253.eml
# emails-1/54252.eml
# emails-1/54246.eml
# emails-1/57029.eml
# emails-1/57015.eml
# emails-1/54285.eml
# found string in file b'visit' 54285.eml
# found string in file b'visit' 54285.eml
# emails-1/54124.eml
# emails-1/54130.eml
# emails-1/54118.eml
# emails-1/54115.eml
# emails-1/54101.eml
# emails-1/54129.eml
# emails-1/54288.eml
# emails-1/54263.eml
# emails-1/54277.eml
# emails-1/57018.eml
# emails-1/57024.eml
# found string in file b'meeting' 57024.eml
# found string in file b'meeting' 57024.eml
# found string in file b'meeting' 57024.eml
# found string in file b'meeting' 57024.eml
# emails-1/57025.eml
# found string in file b'meeting' 57025.eml
# found string in file b'meeting' 57025.eml
# found string in file b'meeting' 57025.eml
# emails-1/54276.eml
# emails-1/57019.eml
# emails-1/54262.eml
# emails-1/54289.eml
# emails-1/54128.eml
# emails-1/54100.eml
# emails-1/54114.eml
# invalid
# emails-1/54102.eml
# emails-1/54116.eml
# emails-1/54274.eml
# emails-1/54260.eml
# emails-1/57027.eml
# found string in file b'meeting' 57027.eml
# found string in file b'meeting' 57027.eml
# emails-1/54248.eml
# emails-1/57026.eml
# invalid
# emails-1/54249.eml
# emails-1/54261.eml
# emails-1/54275.eml
# emails-1/54117.eml
# found string in file b'visit' 54117.eml
# found string in file b'visit' 54117.eml
# emails-1/54103.eml
# emails-1/54107.eml
# emails-1/54113.eml
# emails-1/57022.eml
# emails-1/54259.eml
# found string in file b'meeting' 54259.eml
# found string in file b'event' 54259.eml
# found string in file b'meeting' 54259.eml
# found string in file b'event' 54259.eml
# found string in file b'meeting' 54259.eml
# found string in file b'event' 54259.eml
# emails-1/54271.eml
# found string in file b'travel' 54271.eml
# found string in file b'trip' 54271.eml
# found string in file b'visit' 54271.eml
# found string in file b'event' 54271.eml
# found string in file b'travel' 54271.eml
# found string in file b'trip' 54271.eml
# found string in file b'visit' 54271.eml
# found string in file b'event' 54271.eml
# found string in file b'travel' 54271.eml
# found string in file b'trip' 54271.eml
# found string in file b'visit' 54271.eml
# found string in file b'event' 54271.eml
# found string in file b'travel' 54271.eml
# found string in file b'trip' 54271.eml
# found string in file b'visit' 54271.eml
# found string in file b'event' 54271.eml
# found string in file b'travel' 54271.eml
# found string in file b'trip' 54271.eml
# found string in file b'visit' 54271.eml
# found string in file b'event' 54271.eml
# found string in file b'travel' 54271.eml
# found string in file b'trip' 54271.eml
# found string in file b'visit' 54271.eml
# found string in file b'event' 54271.eml
# found string in file b'travel' 54271.eml
# found string in file b'trip' 54271.eml
# found string in file b'visit' 54271.eml
# found string in file b'event' 54271.eml
# found string in file b'travel' 54271.eml
# found string in file b'trip' 54271.eml
# found string in file b'visit' 54271.eml
# found string in file b'event' 54271.eml
# found string in file b'travel' 54271.eml
# found string in file b'trip' 54271.eml
# found string in file b'visit' 54271.eml
# found string in file b'event' 54271.eml
# found string in file b'travel' 54271.eml
# found string in file b'trip' 54271.eml
# found string in file b'visit' 54271.eml
# found string in file b'event' 54271.eml
# found string in file b'travel' 54271.eml
# found string in file b'trip' 54271.eml
# found string in file b'visit' 54271.eml
# found string in file b'event' 54271.eml
# emails-1/54265.eml
# emails-1/54264.eml
# emails-1/54270.eml
# emails-1/54258.eml
# emails-1/57023.eml
# emails-1/54112.eml
# found string in file b'event' 54112.eml
# found string in file b'event' 54112.eml
# found string in file b'event' 54112.eml
# found string in file b'event' 54112.eml
# emails-1/54106.eml
# emails-1/54138.eml
# found string in file b'visit' 54138.eml
# emails-1/54110.eml
# emails-1/54104.eml
# found string in file b'travel' 54104.eml
# found string in file b'visit' 54104.eml
# found string in file b'travel' 54104.eml
# found string in file b'visit' 54104.eml
# found string in file b'travel' 54104.eml
# found string in file b'visit' 54104.eml
# found string in file b'travel' 54104.eml
# found string in file b'visit' 54104.eml
# found string in file b'travel' 54104.eml
# found string in file b'visit' 54104.eml
# emails-1/57021.eml
# found string in file b'travel' 57021.eml
# found string in file b'travel' 57021.eml
# found string in file b'travel' 57021.eml
# found string in file b'travel' 57021.eml
# emails-1/54266.eml
# emails-1/57009.eml
# emails-1/54272.eml
# emails-1/54273.eml
# emails-1/54267.eml
# emails-1/57008.eml
# found string in file b'event' 57008.eml
# emails-1/57020.eml
# invalid
# emails-1/54105.eml
# emails-1/54111.eml
# emails-1/54139.eml
# found string in file b'event' 54139.eml
# found string in file b'event' 54139.eml
# emails-1/54189.eml
# found string in file b'trip' 54189.eml
# found string in file b'visit' 54189.eml
# found string in file b'trip' 54189.eml
# found string in file b'visit' 54189.eml
# found string in file b'trip' 54189.eml
# found string in file b'visit' 54189.eml
# emails-1/54176.eml
# emails-1/54162.eml
# found string in file b'trip' 54162.eml
# found string in file b'meeting' 54162.eml
# found string in file b'trip' 54162.eml
# found string in file b'meeting' 54162.eml
# found string in file b'trip' 54162.eml
# found string in file b'meeting' 54162.eml
# found string in file b'trip' 54162.eml
# found string in file b'meeting' 54162.eml
# found string in file b'trip' 54162.eml
# found string in file b'meeting' 54162.eml
# found string in file b'trip' 54162.eml
# found string in file b'meeting' 54162.eml
# found string in file b'trip' 54162.eml
# found string in file b'meeting' 54162.eml
# emails-1/54200.eml
# emails-1/54214.eml
# emails-1/54228.eml
# found string in file b'meeting' 54228.eml
# emails-1/54229.eml
# emails-1/54215.eml
# found string in file b'travel' 54215.eml
# found string in file b'trip' 54215.eml
# found string in file b'visit' 54215.eml
# found string in file b'event' 54215.eml
# found string in file b'travel' 54215.eml
# found string in file b'trip' 54215.eml
# found string in file b'visit' 54215.eml
# found string in file b'event' 54215.eml
# found string in file b'travel' 54215.eml
# found string in file b'trip' 54215.eml
# found string in file b'visit' 54215.eml
# found string in file b'event' 54215.eml
# found string in file b'travel' 54215.eml
# found string in file b'trip' 54215.eml
# found string in file b'visit' 54215.eml
# found string in file b'event' 54215.eml
# found string in file b'travel' 54215.eml
# found string in file b'trip' 54215.eml
# found string in file b'visit' 54215.eml
# found string in file b'event' 54215.eml
# found string in file b'travel' 54215.eml
# found string in file b'trip' 54215.eml
# found string in file b'visit' 54215.eml
# found string in file b'event' 54215.eml
# found string in file b'travel' 54215.eml
# found string in file b'trip' 54215.eml
# found string in file b'visit' 54215.eml
# found string in file b'event' 54215.eml
# found string in file b'travel' 54215.eml
# found string in file b'trip' 54215.eml
# found string in file b'visit' 54215.eml
# found string in file b'event' 54215.eml
# emails-1/54201.eml
# emails-1/54163.eml
# emails-1/54177.eml
# emails-1/54188.eml
# emails-1/56789.eml
# emails-1/54161.eml
# emails-1/54175.eml
# emails-1/54149.eml
# emails-1/56399.eml
# emails-1/54217.eml
# emails-1/56400.eml
# emails-1/54203.eml
# emails-1/54202.eml
# emails-1/56401.eml
# emails-1/54216.eml
# found string in file b'meeting' 54216.eml
# emails-1/56398.eml
# emails-1/54148.eml
# invalid
# emails-1/54174.eml
# emails-1/54160.eml
# emails-1/56788.eml
# found string in file b'event' 56788.eml
# emails-1/56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# found string in file b'travel' 56798.eml
# found string in file b'visit' 56798.eml
# found string in file b'meeting' 56798.eml
# found string in file b'tour' 56798.eml
# found string in file b'wander' 56798.eml
# found string in file b'event' 56798.eml
# emails-1/54158.eml
# found string in file b'visit' 54158.eml
# found string in file b'meeting' 54158.eml
# emails-1/54164.eml
# found string in file b'event' 54164.eml
# found string in file b'event' 54164.eml
# emails-1/54170.eml
# found string in file b'meeting' 54170.eml
# emails-1/56808.eml
# emails-1/56388.eml
# emails-1/54212.eml
# emails-1/54206.eml
# emails-1/56377.eml
# invalid
# emails-1/54207.eml
# found string in file b'meeting' 54207.eml
# found string in file b'meeting' 54207.eml
# emails-1/56376.eml
# emails-1/54213.eml
# emails-1/56389.eml
# emails-1/56809.eml
# emails-1/54171.eml
# emails-1/54165.eml
# found string in file b'event' 54165.eml
# found string in file b'event' 54165.eml
# found string in file b'event' 54165.eml
# emails-1/54159.eml
# found string in file b'event' 54159.eml
# emails-1/56799.eml
# emails-1/54198.eml
# found string in file b'visit' 54198.eml
# found string in file b'meeting' 54198.eml
# found string in file b'event' 54198.eml
# found string in file b'visit' 54198.eml
# found string in file b'meeting' 54198.eml
# found string in file b'event' 54198.eml
# found string in file b'visit' 54198.eml
# found string in file b'meeting' 54198.eml
# found string in file b'event' 54198.eml
# found string in file b'visit' 54198.eml
# found string in file b'meeting' 54198.eml
# found string in file b'event' 54198.eml
# emails-1/54173.eml
# emails-1/54167.eml
# emails-1/54239.eml
# found string in file b'visit' 54239.eml
# emails-1/56374.eml
# found string in file b'visit' 56374.eml
# found string in file b'event' 56374.eml
# found string in file b'visit' 56374.eml
# found string in file b'event' 56374.eml
# found string in file b'visit' 56374.eml
# found string in file b'event' 56374.eml
# emails-1/54205.eml
# emails-1/54211.eml
# emails-1/54210.eml
# emails-1/56375.eml
# emails-1/54204.eml
# emails-1/54238.eml
# emails-1/54166.eml
# emails-1/54172.eml
# emails-1/54199.eml

# %%
def coref_resolution(text):
    """Function that executes coreference resolution on a given text"""
    doc = nlp(text)
    # fetches tokens with whitespaces from spacy document
    tok_list = list(token.text_with_ws for token in doc)
    for cluster in doc._.coref_clusters:
        # get tokens from representative cluster name
        cluster_main_words = set(cluster.main.text.split(' '))
        for coref in cluster:
            if coref is not None:
                if coref != cluster.main:  # if coreference element is not the representative element of that cluster
                    if coref.text != cluster.main.text and bool(set(coref.text.split(' ')).intersection(cluster_main_words)) == False:
                    # if coreference element text and representative element text are not equal and none of the coreference element words are in representative element. This was done to handle nested coreference scenarios
                        tok_list[coref.start] = cluster.main.text + \
                            doc[coref.end-1].whitespace_
                        for i in range(coref.start+1, coref.end):
                            tok_list[i] = ""

    return "".join(tok_list)

# %%
def textcleaning(text):
    ###tokenising the email text
# define punctuation
    punctuations = '''!()-[]{};:'"\<>/?@#$%^&*_~'''


# Replace all occurrences of character s with an empty string

    text = re.sub('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', '', text, flags=re.MULTILINE)
    text = text.replace("httpgetwrap"," ")
    text= text.replace(" Sec. ", " ")
    text= text.replace(" Rep. ", " ")
    text= text.replace(" Sen. ", " ")
    text= text.replace(" U.S ", "US")
    text = re.sub('\s+',' ',text)
#text = text.replace("today",msg['Date'])
#print(text)
# remove punctuation from the string
    no_punct = ""
    for char in text:
        if char not in punctuations:
            no_punct = no_punct + char
    return no_punct

# %%
def coref_resolution(text):
    """Function that executes coreference resolution on a given text"""
    doc = nlp(text)
    # fetches tokens with whitespaces from spacy document
    tok_list = list(token.text_with_ws for token in doc)
    for cluster in doc._.coref_clusters:
        # get tokens from representative cluster name
        cluster_main_words = set(cluster.main.text.split(' '))
        for coref in cluster:
            if coref is not None:
                if coref != cluster.main:  # if coreference element is not the representative element of that cluster
                    if coref.text != cluster.main.text and bool(set(coref.text.split(' ')).intersection(cluster_main_words)) == False:
                    # if coreference element text and representative element text are not equal and none of the coreference element words are in representative element. This was done to handle nested coreference scenarios
                        tok_list[coref.start] = cluster.main.text + \
                            doc[coref.end-1].whitespace_
                        for i in range(coref.start+1, coref.end):
                            tok_list[i] = ""

    return "".join(tok_list)
